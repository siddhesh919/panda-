# %%
import pandas as pd

# %%
df=pd.read_csv('survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option('display.max_column',85)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
schema_df=pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
pd.set_option('display.max_rows',85)

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
people={'first':['sid','shubhya','sayali'],
       'last':['balsaraf','khamkar','patekar'],
       'email':['sid@gmail.com','shubh@gmail.com','sayali@gmail.com']}

# %%
df1=pd.DataFrame(people)

# %%
df1
# Out:
#      first      last             email
# 0      sid  balsaraf     sid@gmail.com
# 1  shubhya   khamkar   shubh@gmail.com
# 2   sayali   patekar  sayali@gmail.com

# %%
df1['email']
# Out:
# 0       sid@gmail.com
# 1     shubh@gmail.com
# 2    sayali@gmail.com
# Name: email, dtype: object

# %%
df1.email
# Out:
# 0       sid@gmail.com
# 1     shubh@gmail.com
# 2    sayali@gmail.com
# Name: email, dtype: object

# %%
df1[['last','email']]
# Out:
#        last             email
# 0  balsaraf     sid@gmail.com
# 1   khamkar   shubh@gmail.com
# 2   patekar  sayali@gmail.com

# %%
df1.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df1.iloc[0]
# Out:
# first              sid
# last          balsaraf
# email    sid@gmail.com
# Name: 0, dtype: object

# %%
df1.iloc[[0,1]]
# Out:
#      first      last            email
# 0      sid  balsaraf    sid@gmail.com
# 1  shubhya   khamkar  shubh@gmail.com

# %%
df1.iloc[[0,1],2]
# Out:
# 0      sid@gmail.com
# 1    shubh@gmail.com
# Name: email, dtype: object

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
df.loc[0,'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[[0,1,2],'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:2,'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:2,'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %%
df1
# Out:
#      first      last             email
# 0      sid  balsaraf     sid@gmail.com
# 1  shubhya   khamkar   shubh@gmail.com
# 2   sayali   patekar  sayali@gmail.com

# %%
df1.set_index('email')
# Out:
#                     first      last
# email
# sid@gmail.com         sid  balsaraf
# shubh@gmail.com   shubhya   khamkar
# sayali@gmail.com   sayali   patekar

# %%
df1
# Out:
#      first      last             email
# 0      sid  balsaraf     sid@gmail.com
# 1  shubhya   khamkar   shubh@gmail.com
# 2   sayali   patekar  sayali@gmail.com

# %%
df1.set_index('email',inplace=True)

# %%
df1
# Out:
#                     first      last
# email
# sid@gmail.com         sid  balsaraf
# shubh@gmail.com   shubhya   khamkar
# sayali@gmail.com   sayali   patekar

# %%
df1.index
# Out:
# Index(['sid@gmail.com', 'shubh@gmail.com', 'sayali@gmail.com'], dtype='object', name='email')

# %%
df1.loc['sid@gmail.com']
# Out:
# first         sid
# last     balsaraf
# Name: sid@gmail.com, dtype: object

# %%
df1.loc['sid@gmail.com','last']
# Out:
# 'balsaraf'

# %%
df1.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\siddhesh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-028cb489992c> in <module>
# ...

# %%
df1.iloc[0]

# %%
df1.reset_index(inplace=True)

# %%
df1

# %%
df=pd.read_csv('survey_results_public.csv',index_col='Respondent')

# %%
df

# %%
df.loc[1]

# %%
schema_df=pd.read_csv('survey_results_schema.csv',index_col='Column')

# %%
schema_df

# %%
schema_df.loc['Hobbyist']

# %%
schema_df.loc['MgrIdiot']

# %%
schema_df.loc['MgrIdiot','QuestionText']

# %%
schema_df.sort_index()

# %%
schema_df.sort_index(ascending=False)

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df

# %%
df1

# %%
df1['last']=='balsaraf'

# %%
filt= (df1['last']=='balsaraf')

# %%
df1[filt]

# %%
df1[df1['last']=='balsaraf']

# %%
df1.loc[filt]

# %%
df1.loc[filt,'email']

# %%
filt= (df1['last']=='balsaraf') & (df1['first']=='sid')

# %%
df1.loc[filt,'email']

# %%
filt= (df1['last']=='patekar') | (df1['first']=='sid')

# %%
df1.loc[filt,'email']

# %%
df1.loc[~filt,'email']

# %%
df.head()

# %%
high_salary= (df['ConvertedComp']>70000)

# %%
df.loc[high_salary]

# %%
df.loc[high_salary,['Country','ConvertedComp','LanguageWorkedWith']]

# %%
countries=['United Kingdom','Germany','Canada','United States','India']

# %%
filt=df['Country'].isin(countries)

# %%
df.loc[filt,'Country']

# %%
filt=df['LanguageWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[filt,'LanguageWorkedWith']

# %%
print(df.loc[filt,'LanguageWorkedWith'])

# %%
people={'first':['sid','shubhya','sayali'],
       'last':['balsaraf','khamkar','patekar'],
       'email':['sid@gmail.com','shubh@gmail.com','sayali@gmail.com']}

# %%
df1=pd.DataFrame(people)

# %%
df1

# %%
df1.columns

# %%
df1.columns=['first_name','last_name','email']

# %%
df1

# %%
df1.columns=[x.upper() for x in df1.columns]

# %%
df1

# %%
df1.columns=df1.columns.str.replace(' ',"_")

# %%
df1

# %%
df1.columns=df1.columns.str.replace('_'," ")

# %%
df1

# %%
df1.columns=df1.columns.str.replace(' ',"_")

# %%
df1.columns=[x.lower() for x in df1.columns]

# %%
df1

# %%
df1.rename(columns={'first_name':'first','last_name':'last' })

# %%
df1

# %%
df1.rename(columns={'first_name':'first','last_name':'last' },inplace=True)

# %%
df1

# %%
df1.loc[2]

# %%
df1.loc[2]=['Sayali' ,'Patekar','sayli 919@gmail.com']

# %%
df1

# %%
df1.loc[2,['first','last','email']]=['sayali','patekar','sayali@gmail.com']

# %%
df1

# %%
df1.at[2,'first']='Sayali'

# %%
df1

# %%
filt=df1['first']=='Sayali'
df1[filt]['first']='s'

# %%
filt=df1['first']=='Sayali'
df1.loc[filt,'first']='sayali'

# %%
df1

# %%
df1['email'].str.lower()

# %%
df1['email']=df1['email'].str.lower()

# %%
df1

# %%
df1['email'].apply(len)

# %%
def update_email(email):
    return email.upper()

# %%
df1['email']=df1['email'].apply(update_email)

# %%
df1

# %%
lower_email=lambda email : email.lower()

# %%
df1['email']=df1['email'].apply(lower_email)

# %%
df1

# %%
df1['email']=df1['email'].apply(lambda x:x.lower())

# %% [markdown]
# #

# %%
df1

# %%
df1['email'].apply(len)

# %%
df1.apply(len)

# %%
df1.apply(len,axis='columns')

# %%
df1.apply(pd.Series.min)

# %%
df1.apply(lambda x:x.min())

# %%
df1.applymap(len)

# %%
df1.applymap(str.lower)

# %%
df1['first'].map({'sid':'siddhesh','shubhya':'shubham'})

# %%
df1['first'].replace({'sid':'siddhesh','shubhya':'shubham'})

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'},inplace=True)

# %%
df

# %%
df['Hobbyist'].map({'Yes':True,'No':False})

# %%
df['Hobbyist']=df['Hobbyist'].map({'Yes':True,'No':False})

# %%
df1['first']+ ' ' + df1['last']

# %%
df1.drop(columns=['first','last'])

# %%
df1['first_name']=df1['first']+ ' ' + df1['last']

# %%
df1

# %%
df1['first_name'].str.split(" ",expand=True)

# %%
df1[['first','last']]=df1['first_name'].str.split(" ",expand=True)

# %%
df1

# %%
df1.append({'first':'Tony'}, ignore_index=True)

# %%
people={'first':['dhanshree','priyanka'],
       'last':['shinde','hanchate'],
       'email':['ss','cc',]}

# %%
df2=pd.DataFrame(people)

# %%
df2

# %%
df1.append(df2,ignore_index=True,)

# %%
df1=df1.append(df2,ignore_index=True,)

# %%
df1

# %%
df1.drop(index=4)

# %%
df1.drop(index=df1[df1['last']=='shinde'].index)

# %%
df1.sort_values(by ='last')

# %%
df1.sort_values(by ='last',ascending=False)

# %%
df1.sort_values(by =['last','first'],ascending=False)

# %%
df1.sort_values(by =['last','first'],ascending=[False,True],inplace=True)

# %%
df1

# %%
df1.sort_index()

# %%
df1['first'].sort_values()

# %%
df1

# %%
df.sort_values(by='Country',inplace=True)

# %%
df

# %%
df['Country'].head(50)

# %%
df[['Country','SalaryUSD']].head(50)

# %%
df.sort_values(by=['Country','SalaryUSD'],ascending=[True,False],inplace=True)

# %%
df[['Country','SalaryUSD']].head(50)

# %%
df['SalaryUSD'].nlargest(10)

# %%
df.nlargest(10,'SalaryUSD')

# %%
df.nsmallest(10,'SalaryUSD')

# %%
df5=pd.read_csv('survey_results_public.csv')

# %%
df5['ConvertedComp']
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: ConvertedComp, Length: 88883, dtype: float64

# %%
df5['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df5.median()
# Out:
# Respondent       44442.0
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df5.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df5['ConvertedComp'].describe()
# Out:
# count    5.582300e+04
# mean     1.271107e+05
# std      2.841523e+05
# min      0.000000e+00
# 25%      2.577750e+04
# 50%      5.728700e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
df5['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df5['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df5['SocialMedia']
# Out:
# 0          Twitter
# 1        Instagram
# 2           Reddit
# 3           Reddit
# 4         Facebook
#            ...
# 88878      YouTube
# 88879          NaN
# 88880          NaN
# 88881          NaN
# 88882     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
df5['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df5['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df5['Country'].value_counts()
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Sao Tome and Principe                   1
# Dominica                                1
# Saint Kitts and Nevis                   1
# Saint Vincent and the Grenadines        1
# Timor-Leste                             1
# Name: Country, Length: 179, dtype: int64

# %%
country_grp=df5.groupby(['Country'])

# %%
country_grp

# %%
country_grp.get_group('India')
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
filt=df5['Country']=='India'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# WeChat 微信                      5
# Hello                          5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_grp['SocialMedia'].value_counts().loc['Japan']
# Out:
# SocialMedia
# Twitter                     95
# Facebook                    76
# YouTube                     59
# Reddit                      54
# I don't use social media    24
# Instagram                   21
# WhatsApp                    16
# LinkedIn                    11
# WeChat 微信                    6
# VK ВКонта́кте                1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['Japan']
# Out:
# SocialMedia
# Twitter                     0.261708
# Facebook                    0.209366
# YouTube                     0.162534
# Reddit                      0.148760
# I don't use social media    0.066116
# Instagram                   0.057851
# WhatsApp                    0.044077
# LinkedIn                    0.030303
# WeChat 微信                   0.016529
# VK ВКонта́кте               0.002755
# Name: SocialMedia, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_grp['ConvertedComp'].agg(['median','mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt=df5['Country']=='India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].str.contains('python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-693a9faf9472> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('python').sum()
#
# c:\users\siddhesh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     702
#     703         raise AttributeError(
# --> 704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#     706
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].value_counts().loc['India']
# Out:
# LanguageWorkedWith
# Java                           224
# HTML/CSS;JavaScript;PHP;SQL    199
# HTML/CSS;JavaScript            165
# HTML/CSS;JavaScript;PHP        134
# C#;HTML/CSS;JavaScript;SQL     124
#                               ...
# SQL;Other(s):                    1
# SQL;VBA;Other(s):                1
# Scala                            1
# Scala;Other(s):                  1
# Swift;Other(s):                  1
# Name: LanguageWorkedWith, Length: 2914, dtype: int64

# %%
country_grp['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_respondents=df5['Country'].value_counts()

# %%
country_respondents
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Sao Tome and Principe                   1
# Dominica                                1
# Saint Kitts and Nevis                   1
# Saint Vincent and the Grenadines        1
# Timor-Leste                             1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python=country_grp['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())

# %%
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df=pd.concat([country_respondents,country_uses_python],axis='columns',sort=False)

# %%
python_df
# Out:
#                                   Country  LanguageWorkedWith
# United States                       20949               10083
# India                                9061                3105
# Germany                              5866                2451
# United Kingdom                       5737                2384
# Canada                               3395                1558
# ...                                   ...                 ...
# Sao Tome and Principe                   1                   1
# Dominica                                1                   1
# Saint Kitts and Nevis                   1                   0
# Saint Vincent and the Grenadines        1                   0
# Timor-Leste                             1                   1
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'Country':'no of responde',"LanguageWorkedWith":"knowspython"},inplace=True)

# %%
python_df
# Out:
#                                   no of responde  knowspython
# United States                              20949        10083
# India                                       9061         3105
# Germany                                     5866         2451
# United Kingdom                              5737         2384
# Canada                                      3395         1558
# ...                                          ...          ...
# Sao Tome and Principe                          1            1
# Dominica                                       1            1
# Saint Kitts and Nevis                          1            0
# Saint Vincent and the Grenadines               1            0
# Timor-Leste                                    1            1
#
# [179 rows x 2 columns]

# %%
python_df['percent']=python_df['knowspython']/python_df['no of responde'] *100

# %%
python_df
# Out:
#                                   no of responde  knowspython     percent
# United States                              20949        10083   48.131176
# India                                       9061         3105   34.267741
# Germany                                     5866         2451   41.783157
# United Kingdom                              5737         2384   41.554820
# Canada                                      3395         1558   45.891016
# ...                                          ...          ...         ...
# Sao Tome and Principe                          1            1  100.000000
# Dominica                                       1            1  100.000000
# Saint Kitts and Nevis                          1            0    0.000000
# Saint Vincent and the Grenadines               1            0    0.000000
# Timor-Leste                                    1            1  100.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by='percent',ascending=False,inplace=True)

# %%
python_df.head(50)
# Out:
#                                   no of responde  knowspython     percent
# Timor-Leste                                    1            1  100.000000
# Dominica                                       1            1  100.000000
# Sao Tome and Principe                          1            1  100.000000
# Niger                                          1            1  100.000000
# Turkmenistan                                   7            6   85.714286
# Mauritania                                     7            5   71.428571
# Guyana                                         3            2   66.666667
# Guinea                                         3            2   66.666667
# Bahamas                                        3            2   66.666667
# Uganda                                        72           47   65.277778
# Iceland                                       49           30   61.224490
# Haiti                                          5            3   60.000000
# ...

# %%
import pandas as pd
import numpy as np

# %%
people={'first':['sid','shubhya','sayali','ramesh',np.nan,None,'NA'],
       'last':['balsaraf','khamkar','patekar','bhai',np.nan,np.nan,'Missing'],
       'email':['sid@gmail.com','shubh@gmail.com','sayali@gmail.com',None,np.nan,'anonyms@gmail.com','NA'],
       'age':['33','55','63','36',None,None,'missing']}

# %%
df6=pd.DataFrame(people)

# %%
df6
# Out:
#      first      last              email      age
# 0      sid  balsaraf      sid@gmail.com       33
# 1  shubhya   khamkar    shubh@gmail.com       55
# 2   sayali   patekar   sayali@gmail.com       63
# 3   ramesh      bhai               None       36
# 4      NaN       NaN                NaN     None
# 5     None       NaN  anonyms@gmail.com     None
# 6       NA   Missing                 NA  missing

# %%
df6.dropna()
# Out:
#      first      last             email      age
# 0      sid  balsaraf     sid@gmail.com       33
# 1  shubhya   khamkar   shubh@gmail.com       55
# 2   sayali   patekar  sayali@gmail.com       63
# 6       NA   Missing                NA  missing

# %%
df6.dropna(axis='index',how='any')
# Out:
#      first      last             email      age
# 0      sid  balsaraf     sid@gmail.com       33
# 1  shubhya   khamkar   shubh@gmail.com       55
# 2   sayali   patekar  sayali@gmail.com       63
# 6       NA   Missing                NA  missing

# %%
df6.dropna(axis='index',how='all')
# Out:
#      first      last              email      age
# 0      sid  balsaraf      sid@gmail.com       33
# 1  shubhya   khamkar    shubh@gmail.com       55
# 2   sayali   patekar   sayali@gmail.com       63
# 3   ramesh      bhai               None       36
# 5     None       NaN  anonyms@gmail.com     None
# 6       NA   Missing                 NA  missing

# %%
df6.dropna(axis='columns',how='all')
# Out:
#      first      last              email      age
# 0      sid  balsaraf      sid@gmail.com       33
# 1  shubhya   khamkar    shubh@gmail.com       55
# 2   sayali   patekar   sayali@gmail.com       63
# 3   ramesh      bhai               None       36
# 4      NaN       NaN                NaN     None
# 5     None       NaN  anonyms@gmail.com     None
# 6       NA   Missing                 NA  missing

# %%
df6.dropna(axis='columns',how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df6.dropna(axis='index',how='any',subset=['email'])
# Out:
#      first      last              email      age
# 0      sid  balsaraf      sid@gmail.com       33
# 1  shubhya   khamkar    shubh@gmail.com       55
# 2   sayali   patekar   sayali@gmail.com       63
# 5     None       NaN  anonyms@gmail.com     None
# 6       NA   Missing                 NA  missing

# %%
df6.dropna(axis='index',how='any',subset=['email','last'])
# Out:
#      first      last             email      age
# 0      sid  balsaraf     sid@gmail.com       33
# 1  shubhya   khamkar   shubh@gmail.com       55
# 2   sayali   patekar  sayali@gmail.com       63
# 6       NA   Missing                NA  missing

# %%
df6
# Out:
#      first      last              email      age
# 0      sid  balsaraf      sid@gmail.com       33
# 1  shubhya   khamkar    shubh@gmail.com       55
# 2   sayali   patekar   sayali@gmail.com       63
# 3   ramesh      bhai               None       36
# 4      NaN       NaN                NaN     None
# 5     None       NaN  anonyms@gmail.com     None
# 6       NA   Missing                 NA  missing

# %%
df6.replace('NA',np.nan,inplace=True)
df6.replace('Missing',np.nan,inplace=True)

# %%
df6
# Out:
#      first      last              email   age
# 0      sid  balsaraf      sid@gmail.com    33
# 1  shubhya   khamkar    shubh@gmail.com    55
# 2   sayali   patekar   sayali@gmail.com    63
# 3   ramesh      bhai               None    36
# 4      NaN       NaN                NaN  None
# 5     None       NaN  anonyms@gmail.com  None
# 6      NaN       NaN                NaN   NaN

# %%
df6.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df6.fillna('missing')
# Out:
#      first      last              email      age
# 0      sid  balsaraf      sid@gmail.com       33
# 1  shubhya   khamkar    shubh@gmail.com       55
# 2   sayali   patekar   sayali@gmail.com       63
# 3   ramesh      bhai            missing       36
# 4  missing   missing            missing  missing
# 5  missing   missing  anonyms@gmail.com  missing
# 6  missing   missing            missing  missing

# %%
df6.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
df6['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-33581b32b18d> in <module>
# ----> 1 df6['age'].mean()
#
# c:\users\siddhesh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11473             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11474         return self._reduce(
# > 11475             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11476         )
#   11477
#
# c:\users\siddhesh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4247                 )
#    4248             with np.errstate(all="ignore"):
# -> 4249                 return op(delegate, skipna=skipna, **kwds)
#    4250
# ...

# %%
df6['age']=df6['age'].astype(float)

# %%
df6.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df6['age'].mean()
# Out:
# 46.75

# %%
na_vals=['NA','Missing']
df=pd.read_csv('survey_results_public.csv',index_col='Respondent',na_values=na_vals)

# %%
df['YearsCode'].head(10)
# Out:
# 0      4
# 1    NaN
# 2      3
# 3      3
# 4     16
# 5     13
# 6      6
# 7      8
# 8     12
# 9     12
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-eaa6cdf065a6> in <module>
# ----> 1 df['YearsCode'].mean()
#
# c:\users\siddhesh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11473             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11474         return self._reduce(
# > 11475             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11476         )
#   11477
#
# c:\users\siddhesh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4247                 )
#    4248             with np.errstate(all="ignore"):
# -> 4249                 return op(delegate, skipna=skipna, **kwds)
#    4250
# ...

# %%
df['YearsCode']=df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-c75b77d4e281> in <module>
# ----> 1 df['YearsCode']=df['YearsCode'].astype(float)
#
# c:\users\siddhesh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# c:\users\siddhesh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# ...

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)

# %%
df['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
df['YearsCode']=df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %%
df0=pd.read_csv('ETH_1h.csv')

# %%
df0.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df0.shape
# Out:
# (23674, 7)

# %%
df0.loc[0,'Date']
# Out:
# '2020-03-13 08-PM'

# %%
df0['Date']=pd.to_datetime(df0['Date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\siddhesh\appdata\local\programs\python\python36\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2058         try:
# -> 2059             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2060             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-59-982a08202b23> in <module>
# ----> 1 df0['Date']=pd.to_datetime(df0['Date'])
#
# ...

# %%
df0['Date']=pd.to_datetime(df0['Date'],format='%Y-%m-%d %I-%p')

# %%
df0['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df0.loc[0,'Date'].day_name()
# Out:
# 'Friday'

# %%
d_parser=lambda x: pd.datetime.strptime(x,'%Y-%m-%d %I-%p')
dff=pd.read_csv('ETH_1h.csv',parse_dates=['Date'],date_parser=d_parser)
# Out:
# c:\users\siddhesh\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   """Entry point for launching an IPython kernel.

# %%
dff
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
dff['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
dff['DayOfWeek']=dff['Date'].dt.day_name()

# %%
dff
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
dff['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
dff['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
dff['Date'].max() - dff['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt=(dff['Date']>'2020')
dff[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1743 2020-01-01 05:00:00  ETHUSD  129.56  129.94  129.47  129.83   232163.70
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
#
#       DayOfWeek
# 0        Friday
# ...

# %%
filt=(dff['Date']>='2019') & (dff['Date']<'2020')
dff[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
filt=(dff['Date']>=pd.to_datetime('2019-01-01')) & (dff['Date']<pd.to_datetime('2020-01-01'))
dff[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
dff.set_index('Date',inplace=True)

# %%
dff
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
dff['2019']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     DayOfWeek
# Date
# 2019-12-31 23:00:00   Tuesday
# ...

# %%
dff['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
dff['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.1655902777778

# %%
dff['2020-01':'2020-02'].head(24)
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# 2020-02-29 18:00:00  ETHUSD  225.53  226.17  224.50  225.09   496543.91
# 2020-02-29 17:00:00  ETHUSD  222.68  225.53  222.24  225.53   611136.47
# 2020-02-29 16:00:00  ETHUSD  224.17  225.93  222.36  222.68   694384.75
# 2020-02-29 15:00:00  ETHUSD  223.35  225.88  221.80  224.17   550893.74
# 2020-02-29 14:00:00  ETHUSD  224.42  224.42  221.15  223.35  1479928.44
# 2020-02-29 13:00:00  ETHUSD  225.29  225.37  222.87  224.42  1076646.41
# 2020-02-29 12:00:00  ETHUSD  226.50  226.50  224.14  225.29   359022.09
# ...

# %%
dff['2020-01-01']['High'].max()
# Out:
# 132.68

# %%
dff['High'].resample('D').max()
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
highs=dff['High'].resample('D').max()

# %%
highs['2020-01-01']
# Out:
# 132.68

# %%
# %matplotlib inline

# %%
highs.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dff.resample('w').mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
dff.resample('w').agg({'Close':'mean','High':'max','Low':'min','Volume':'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %%
dfl=pd.read_csv('survey_results_public.csv')

# %%
filt=(dfl['Country']=='India')
indiadf=dfl.loc[filt]
indiadf
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
indiadf.to_csv('1stmodified.csv')

# %%
indiadf.to_csv('1stmodified.tsv',sep='\t')

# %%
indiadf.to_excel('1stmodified.xlsx')

# %%
test=pd.read_excel('1stmodified.xlsx' ,  index_col='Respondent',engine='openpyxl')

# %%
indiadf.to_json('1stmodified.json')

# %%
indiadf.to_json('1stmodified.json',orient='records',lines=True)

# %%
test=pd.read_json('1stmodified.json',orient='records',lines=True)

# %%
test
# Out:
#       Respondent                              MainBranch Hobbyist  \
# 0              8             I code primarily as a hobby      Yes
# 1             10          I am a developer by profession      Yes
# 2             15  I am a student who is learning to code      Yes
# 3             50          I am a developer by profession      Yes
# 4             65          I am a developer by profession      Yes
# ...          ...                                     ...      ...
# 9056       77339                                    None      Yes
# 9057       79795                                    None      Yes
# 9058       83862                                    None      Yes
# 9059       84299                                    None      Yes
# 9060       86012                                    None      Yes
#
#                                             OpenSourcer  \
# 0                               Less than once per year
# 1                            Once a month or more often
# ...
